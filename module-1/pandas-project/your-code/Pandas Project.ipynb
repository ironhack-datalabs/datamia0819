# %%
import pandas as pd 
import csv
import numpy as np

# %%
data = pd.read_csv('/Users/talalagedeon/Ironhack/datamia0819/module-1/GSAF5.csv', engine='python')
data
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
nulls_cols= data.isnull().sum()

# %%
nulls_cols[nulls_cols > 0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
drop_cols = list(nulls_cols[nulls_cols > 1000].index)
data1 = data.drop(drop_cols, axis=1)
data1.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M
# 2  New Smyrna Beach, Volusia County  Surfing             male    M
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M
# 4                       Bells Beach  Surfing             male    M
#
#                                   Injury Fatal (Y/N)  \
# 0                  Minor injury to thigh           N
# 1                   Lacerations to hands           N
# ...

# %%
# amount less than zero after dropping 
nulls_cols[nulls_cols > 0]
drop_cols
# Out:
# ['Age', 'Time', 'Species ', 'Unnamed: 22', 'Unnamed: 23']

# %%
data1.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Injury                    object
# Fatal (Y/N)               object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# dtype: object

# %%
data1['Fatal (Y/N)']=='Y'
data1['Case Number']== data1['Case Number.1'] 
data1[(data1['Case Number.1']== data1['Case Number.2'])&(data1['Case Number']== data1['Case Number.1'])]
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# 11      2016.09.04                                          04-Sep-16  2016
# ...

# %%
data1=data1.drop(['href formula','href','Case Number.1','Case Number.2','pdf'], axis=1)

# %%
data1.set_index('original order', inplace=True)
data1
# Out:
#                  Case Number  \
# original order
# 5993            2016.09.18.c
# 5992            2016.09.18.b
# 5991            2016.09.18.a
# 5990              2016.09.17
# 5989              2016.09.15
# 5988            2016.09.15.R
# 5987              2016.09.11
# 5986              2016.09.07
# 5985              2016.09.06
# 5984            2016.09.05.b
# 5983            2016.09.05.a
# 5982              2016.09.04
# 5981              2016.09.01
# 5980            2016.08.29.b
# 5979            2016.08.29.a
# 5978              2016.08.27
# 5977              2016.08.25
# 5976              2016.08.07
# 5975              2016.08.06
# 5974              2016.08.04
# 5973              2016.07.29
# 5972            2016.07.28.R
# 5971              2016.07.28
# 5970              2016.07.27
# 5969              2016.07.26
# 5968              2016.07.24
# 5967            2016.07.23.b
# 5966            2016.07.23.a
# 5965              2016.07.20
# 5964              2016.07.17
# ...

# %%
stats = data.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                  count         mean          std  min      25%     50%  \
# Year            5992.0  1925.204606   286.473712  0.0  1942.00  1975.0
# original order  5992.0  2997.548899  1729.860210  2.0  1499.75  2997.5
#
#                     75%     max     IQR
# Year            2003.00  2016.0    61.0
# original order  4495.25  5993.0  2995.5

# %%
low_variance= []

for i in data._get_numeric_data():
    minimum= min(data1[data1.columns])
    

print(minimum)
# Out:
# Activity

# %%
# Download csv and see difference in mg

# %%
data1.count()
# Out:
# Case Number               5992
# Date                      5992
# Year                      5992
# Type                      5992
# Country                   5949
# Area                      5590
# Location                  5496
# Activity                  5465
# Name                      5792
# Sex                       5425
# Injury                    5965
# Fatal (Y/N)               5973
# Investigator or Source    5977
# dtype: int64

# %%
# Finding out which country has the most cases
data['Country'].value_counts()
# Out:
# USA                         2116
# AUSTRALIA                   1279
# SOUTH AFRICA                 565
# PAPUA NEW GUINEA             133
# NEW ZEALAND                  125
# BRAZIL                       102
# BAHAMAS                       98
# MEXICO                        81
# ITALY                         71
# FIJI                          62
# PHILIPPINES                   59
# REUNION                       57
# NEW CALEDONIA                 51
# MOZAMBIQUE                    44
# CUBA                          42
# SPAIN                         40
# INDIA                         37
# EGYPT                         36
# CROATIA                       34
# PANAMA                        32
# JAPAN                         32
# IRAN                          29
# SOLOMON ISLANDS               29
# GREECE                        25
# HONG KONG                     24
# JAMAICA                       23
# FRENCH POLYNESIA              22
# INDONESIA                     20
# ...

# %%
data[data['Country']=='USA']['Type'].value_counts()
# Out:
# Unprovoked      1646
# Provoked         204
# Invalid          183
# Boat              38
# Sea Disaster      29
# Boating           16
# Name: Type, dtype: int64

# %%
data[data['Country']=='AUSTRALIA']['Type'].value_counts()
# Out:
# Unprovoked      897
# Provoked        130
# Invalid         113
# Boat             64
# Boating          51
# Sea Disaster     24
# Name: Type, dtype: int64
