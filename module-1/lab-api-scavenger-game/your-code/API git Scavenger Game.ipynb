# %%
import requests
import pandas as pd 
import getpass
import json

# %%
username = 'talalgedeon'
token = getpass.getpass(prompt='Token:', stream=None)

# Create a re-usable session object with the user creds in-built
gh_session = requests.Session()
gh_session.auth = (username, token)
# Out:
# Token:········

# %%
token='594f979339a0a8a7658c2f0cc47b6cf87368868e'

# %%
url = 'https://api.github.com' + '/repos/ironhack-datalabs/madrid-oct-2018/forks'
url
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'

# %%
request = requests.get(url,auth=gh_session.auth)

# %%
json = request.json()

df =pd.DataFrame(json)
df.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'merges_url',
#        'milestones_url', 'mirror_url', 'name', 'node_id', 'notifications_url',
#        'open_issues', 'open_issues_count', 'owner', 'private', 'pulls_url',
#        'pushed_at', 'releases_url', 'size', 'ssh_url', 'stargazers_count',
# ...

# %%
df['language'].unique()
# Out:
# array(['Jupyter Notebook', 'HTML', 'Python'], dtype=object)

# %%
df
# Out:
#                                           archive_url  archived  \
# 0   https://api.github.com/repos/rsennes/mad-oct-2...     False
# 1   https://api.github.com/repos/gggfaria/mad-oct-...     False
# 2   https://api.github.com/repos/nancyulric/mad-oc...     False
# 3   https://api.github.com/repos/lmartinezruizit/d...     False
# 4   https://api.github.com/repos/eye8/madrid-oct-2...     False
# 5   https://api.github.com/repos/ArieHassan/madrid...     False
# 6   https://api.github.com/repos/cmvalma/madrid-oc...     False
# 7   https://api.github.com/repos/criraca/madrid-oc...     False
# 8   https://api.github.com/repos/boyander/madrid-o...     False
# 9   https://api.github.com/repos/AlbertoCastellano...     False
# 10  https://api.github.com/repos/elenajpp/madrid-o...     False
# 11  https://api.github.com/repos/pablobarrio/madri...     False
# 12  https://api.github.com/repos/miriammg/madrid-o...     False
# 13  https://api.github.com/repos/albertogcmr/madri...     False
# ...

# %%
df['language'].unique()
# Out:
# array(['Jupyter Notebook', 'HTML', 'Python'], dtype=object)
