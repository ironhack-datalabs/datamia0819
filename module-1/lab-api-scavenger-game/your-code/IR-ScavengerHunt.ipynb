# %%
import requests
import pandas as pd
import getpass
import json

# %%
#AUTHENTICATION

username = 'Repairmanmanmanman' #My GitHub username
token = getpass.getpass(prompt='Token:', stream=None)

#Create a re-usable session object with the user creds in-built
gh_session = requests.Session()
gh_session.auth = (username, token)
# Out:
# Token:········

# %%
token = '54516396e222fc1b108c4e4729edb9621a0175c4' #my token

# %%
url = 'https://api.github.com' + '/repos/ironhack-datalabs/madrid-oct-2018/forks'
url2 = 'https://api.github.com' + '/repos/ironhack-datalabs/madrid-oct-2018/commits'
url3 = 'https://api.github.com' + '/repos/ironhack-datalabs/scavenger'

# %%
request = requests.get(url, auth=gh_session.auth) #Use my created session
request2 = requests.get(url2, auth=gh_session.auth) #Use my created session
request3 = requests.get(url3, auth=gh_session.auth) #Use my created session

# %%
json = request.json()
json2 = request2.json()
json3 = request3.json()
json
json2
json3
# Out:
# {'id': 162375181,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#  'name': 'scavenger',
#  'full_name': 'ironhack-datalabs/scavenger',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
df = pd.DataFrame(json)
df2 = pd.DataFrame(json2)
df3 = pd.DataFrame(json3)
df.columns
df2
# Out:
#                                          sha  \
# 0   1638e5506e6947b77bfe78761d345476ae80d017
# 1   f332b5e6fcea965dc80f62220d7ee1457b04b90d
# 2   4c048c3efc18cf9d50e34c76919c8049ee7f2dbd
# 3   41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310
# 4   750eb91e4535c14ec4bf03f60cb5756a1c93f68f
# 5   4a8cc3cb64821cb58182a3a94be38f17d27a8e8f
# 6   1501bac01f8183d223a47ca7f23649a5d98d7e00
# 7   6c2a1247d4e13a37261081279f250ffa82ed5c96
# 8   cc02db3df76c8a16ecee3f7a937366ff427a7c3a
# 9   49ba929952728ab17635591cf55137c8af01babb
# 10  ba93368ee5593b15c7b1829f82cbacb9a003476c
# 11  2034c389cb81f30d30f94acc2a5237377d387dc1
# 12  09cf3f0163fe3895128cb322f5450672435ede7e
# 13  825dea0b3aab60bf587130441fab30d8abab775c
# 14  ced5e055e9313f60c57a7daab4ee89eac9f2c409
# 15  2cda9ab92b0f4dbfbe72e39a1bc26b9d7e41d28f
# 16  2db6ca9372c8585a0a894cef5c8be3c51a4547a7
# 17  4887dd8d4b582f6279c6f23114842d3fd071e62a
# 18  14a4c26acde03b2ebff1e1e84da29d60bc532410
# 19  b57627cc8931bdeb56b48bd853beac0b569e6e93
# ...

# %%
#Challenge 1 Answer

df['language'].unique()
# Out:
# array(['Jupyter Notebook', 'HTML', 'Python'], dtype=object)

# %%
df2['commit']
# Out:
# 0     {'author': {'name': 'Marc Pomar', 'email': 'ma...
# 1     {'author': {'name': 'ta-data-bcn', 'email': '4...
# 2     {'author': {'name': 'ta-data-bcn', 'email': '4...
# 3     {'author': {'name': 'Tony Ojeda', 'email': 'to...
# 4     {'author': {'name': 'Michal Monselise', 'email...
# 5     {'author': {'name': 'Michal Monselise', 'email...
# 6     {'author': {'name': 'Michal Monselise', 'email...
# 7     {'author': {'name': 'Michal Monselise', 'email...
# 8     {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 9     {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 10    {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 11    {'author': {'name': 'Michal Monselise', 'email...
# 12    {'author': {'name': 'Michal Monselise', 'email...
# 13    {'author': {'name': 'Michal Monselise', 'email...
# 14    {'author': {'name': 'Michal Monselise', 'email...
# 15    {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 16    {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# ...

# %%
#Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#Count how many commit objects are contained in the array.
df2.columns
df2['commit'].count()
#Answer: There are 30 commit counts in the array.
# Out:
# 30
