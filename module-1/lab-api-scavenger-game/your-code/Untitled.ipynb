# %%
import pandas as pd
import numpy as np
import getpass
import requests

# %%
username = "Luis-Porras"
#token = getpass.getpass(prompt = "Token:",stream=None)
token = "567b8fcec0f0f085715b4b93b841bd34284339f7"
gh_session = requests.Session()
gh_session.auth = (username,token)
token
# Out:
# '567b8fcec0f0f085715b4b93b841bd34284339f7'

# %%
#token = "241f3845a03b8ffdaff3ef5fdb94655692bf4a4f"
url = "https://api.github.com/repos/ironhack-datalabs/datamia0819/forks"

# %%
request = requests.get(url, auth = (username,token))
request
# Out:
# <Response [200]>

# %%
r = request.json()
languages = []
for repo in r:
    if repo["language"] not in languages:
        languages.append(repo["language"])
        
print(languages)
# Out:
# ['Jupyter Notebook']

# %%
r
# Out:
# [{'id': 203243985,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDMyNDM5ODU=',
#   'name': 'datamia0819',
#   'full_name': 'djean062/datamia0819',
#   'private': False,
#   'owner': {'login': 'djean062',
#    'id': 53487043,
#    'node_id': 'MDQ6VXNlcjUzNDg3MDQz',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/53487043?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/djean062',
#    'html_url': 'https://github.com/djean062',
#    'followers_url': 'https://api.github.com/users/djean062/followers',
#    'following_url': 'https://api.github.com/users/djean062/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/djean062/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/djean062/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/djean062/subscriptions',
#    'organizations_url': 'https://api.github.com/users/djean062/orgs',
#    'repos_url': 'https://api.github.com/users/djean062/repos',
# ...

# %%
#Question 2: count commits in the last week
url = "https://api.github.com/repos/ironhack-datalabs/datamia0819/commits"
request = requests.get(url, auth = gh_session.auth)

# %%
r = request.json()
for commit in r:
    print(commit["commit"]["author"]["date"])
print("only one of these 4 commits was done in the last week")
# Out:
# 2019-09-10T15:49:50Z
# 2019-08-19T18:35:04Z
# 2019-08-05T14:38:11Z
# 2019-08-05T14:26:05Z
# only one of these 4 commits was done in the last week

# %%
#question 3: scavenger hunt
url = "https://api.github.com/repos/ironhack-datalabs/scavenger/contents"
repo = requests.get(url, auth = gh_session.auth).json()

# %%
for i in range(len(repo[1:])):
    url = "https://api.github.com/repos/ironhack-datalabs/scavenger/contents"+"/"+repo[i+1]["name"]
    sub_dir = requests.get(url, auth = gh_session.auth).json()
    for j in range(len(sub_dir)):
        #print(sub_dir[j]["name"],"\n")
        if "scavengerhunt" in sub_dir[j]["name"]:
            url2 = "https://api.github.com/repos/ironhack-datalabs/scavenger/contents"+"/"+repo[i+1]["name"]+"/"+sub_dir[j]["name"]
            print(url2)
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534/.0008.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534/.0012.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020/.0007.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351/.0021.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/40303/.0022.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639/.0005.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/45525/.0018.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222/.0016.scavengerhunt
# https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222/.0024.scavengerhunt
# ...
