# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
import requests as r
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
url='https://financialmodelingprep.com/api/v3/financials/income-statement/AAPL'

# %%
r.get(url)
# Out:
# <Response [200]>

# %%
r.get(url).content
# Out:
# b'{\n  "symbol" : "AAPL",\n  "financials" : [ {\n    "date" : "2018-09-29",\n    "Revenue" : "265595000000.0",\n    "Revenue Growth" : "0.1586",\n    "Cost of Revenue" : "163756000000.0",\n    "Gross Profit" : "101839000000.0",\n    "R&D Expenses" : "14236000000.0",\n    "SG&A Expense" : "16705000000.0",\n    "Operating Expenses" : "30941000000.0",\n    "Operating Income" : "70898000000.0",\n    "Interest Expense" : "0.0",\n    "Earnings before Tax" : "72903000000.0",\n    "Income Tax Expense" : "13372000000.0",\n    "Net Income - Non-Controlling int" : "0.0",\n    "Net Income - Discontinued ops" : "0.0",\n    "Net Income" : "59531000000.0",\n    "Preferred Dividends" : "0.0",\n    "Net Income Com" : "59531000000.0",\n    "EPS" : "12.01",\n    "EPS Diluted" : "11.91",\n    "Weighted Average Shs Out" : "4955377000.0",\n    "Weighted Average Shs Out (Dil)" : "5000109000.0",\n    "Dividend per Share" : "2.72",\n    "Gross Margin" : "0.3834",\n    "EBITDA Margin" : "0.316",\n    "EBIT Margin" : "0.2745",\n    "Profit Margin" : "0.224",\n    "Free Cash Flow margin" : "0.2414",\n    "EBITDA" : "83806000000.0",\n    "EBIT" : "72903000000.0",\n    "Consolidated Income" : "59531000000.0",\n    "Earnings Before Tax Margin" : "0.2745",\n    "Net Profit Margin" : "0.2241"\n  }, {\n    "date" : "2017-09-30",\n    "Revenue" : "229234000000.0",\n    "Revenue Growth" : "0.063",\n    "Cost of Revenue" : "141048000000.0",\n    "Gross Profit" : "88186000000.0",\n    "R&D Expenses" : "11581000000.0",\n    "SG&A Expense" : "15261000000.0",\n    "Operating Expenses" : "26842000000.0",\n    "Operating Income" : "61344000000.0",\n    "Interest Expense" : "0.0",\n    "Earnings before Tax" : "64089000000.0",\n    "Income Tax Expense" : "15738000000.0",\n    "Net Income - Non-Controlling int" : "0.0",\n    "Net Income - Discontinued ops" : "0.0",\n    "Net Income" : "48351000000.0",\n    "Preferred Dividends" : "0.0",\n    "Net Income Com" : "48351000000.0",\n    "EPS" : "9.27",\n    "EPS Diluted" : "9.21",\n    "Weighted Average Shs Out" : "5217242000.0",\n    "Weighted Average Shs Out (Dil)" : "5251692000.0",\n    "Dividend per Share" : "2.4",\n    "Gross Margin" : "0.3847",\n    "EBITDA Margin" : "0.324",\n    "EBIT Margin" : "0.2796",\n    "Profit Margin" : "0.211",\n    "Free Cash Flow margin" : "0.2259",\n    "EBITDA" : "74246000000.0",\n    "EBIT" : "64089000000.0",\n    "Consolidated Income" : "48351000000.0",\n    "Earnings Before Tax Margin" : "0.2796",\n    "Net Profit Margin" : "0.2109"\n  }, {\n    "date" : "2016-09-24",\n    "Revenue" : "215639000000.0",\n    "Revenue Growth" : "-0.0773",\n    "Cost of Revenue" : "131376000000.0",\n    "Gross Profit" : "84263000000.0",\n    "R&D Expenses" : "10045000000.0",\n    "SG&A Expense" : "14194000000.0",\n    "Operating Expenses" : "24239000000.0",\n    "Operating Income" : "60024000000.0",\n    "Interest Expense" : "0.0",\n    "Earnings before Tax" : "61372000000.0",\n    "Income Tax Expense" : "15685000000.0",\n    "Net Income - Non-Controlling int" : "0.0",\n    "Net Income - Discontinued ops" : "0.0",\n    "Net Income" : "45687000000.0",\n    "Preferred Dividends" : "0.0",\n    "Net Income Com" : "45687000000.0",\n    "EPS" : "8.35",\n    "EPS Diluted" : "8.31",\n    "Weighted Average Shs Out" : "5470820000.0",\n    "Weighted Average Shs Out (Dil)" : "5500281000.0",\n    "Dividend per Share" : "2.18",\n    "Gross Margin" : "0.3908",\n    "EBITDA Margin" : "0.333",\n    "EBIT Margin" : "0.2846",\n    "Profit Margin" : "0.212",\n    "Free Cash Flow margin" : "0.2481",\n    "EBITDA" : "71877000000.0",\n    "EBIT" : "61372000000.0",\n    "Consolidated Income" : "45687000000.0",\n    "Earnings Before Tax Margin" : "0.2846",\n    "Net Profit Margin" : "0.2119"\n  }, {\n    "date" : "2015-09-26",\n    "Revenue" : "233715000000.0",\n    "Revenue Growth" : "0.2786",\n    "Cost of Revenue" : "140089000000.0",\n    "Gross Profit" : "93626000000.0",\n    "R&D Expenses" : "8067000000.0",\n    "SG&A Expense" ...

# %%
help(r.get)
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the body of the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
request=r.get(url)

# %%
Json=request.json()
Json
# Out:
# {'symbol': 'AAPL',
#  'financials': [{'date': '2018-09-29',
#    'Revenue': '265595000000.0',
#    'Revenue Growth': '0.1586',
#    'Cost of Revenue': '163756000000.0',
#    'Gross Profit': '101839000000.0',
#    'R&D Expenses': '14236000000.0',
#    'SG&A Expense': '16705000000.0',
#    'Operating Expenses': '30941000000.0',
#    'Operating Income': '70898000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '72903000000.0',
#    'Income Tax Expense': '13372000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '59531000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '59531000000.0',
#    'EPS': '12.01',
#    'EPS Diluted': '11.91',
#    'Weighted Average Shs Out': '4955377000.0',
#    'Weighted Average Shs Out (Dil)': '5000109000.0',
#    'Dividend per Share': '2.72',
#    'Gross Margin': '0.3834',
#    'EBITDA Margin': '0.316',
#    'EBIT Margin': '0.2745',
#    'Profit Margin': '0.224',
#    'Free Cash Flow margin': '0.2414',
#    'EBITDA': '83806000000.0',
#    'EBIT': '72903000000.0',
#    'Consolidated Income': '59531000000.0',
#    'Earnings Before Tax Margin': '0.2745',
#    'Net Profit Margin': '0.2241'},
#   {'date': '2017-09-30',
#    'Revenue': '229234000000.0',
#    'Revenue Growth': '0.063',
#    'Cost of Revenue': '141048000000.0',
#    'Gross Profit': '88186000000.0',
#    'R&D Expenses': '11581000000.0',
#    'SG&A Expense': '15261000000.0',
#    'Operating Expenses': '26842000000.0',
#    'Operating Income': '61344000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '64089000000.0',
#    'Income Tax Expense': '15738000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '48351000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '48351000000.0',
#    'EPS': '9.27',
#    'EPS Diluted': '9.21',
#    'Weighted Average Shs Out': '5217242000.0',
#    'Weighted Average Shs Out (Dil)': '5251692000.0',
#    'Dividend per Share': '2.4',
#    'Gross Margin': '0.3847',
#    'EBITDA Margin': '0.324',
#    'EBIT Margin': '0.2796',
#    'Profit Margin': '0.211',
#    'Free Cash Flow margin': '0.2259',
#    'EBITDA': '74246000000.0',
#    'EBIT': '64089000000.0',
#    'Consolidated Income': '48351000000.0',
#    'Earnings Before Tax Margin': '0.2796',
#    'Net Profit Margin': '0.2109'},
#   {'date': '2016-09-24',
#    'Revenue': '215639000000.0',
#    'Revenue Growth': '-0.0773',
#    'Cost of Revenue': '131376000000.0',
#    'Gross Profit': '84263000000.0',
#    'R&D Expenses': '10045000000.0',
#    'SG&A Expense': '14194000000.0',
#    'Operating Expenses': '24239000000.0',
#    'Operating Income': '60024000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '61372000000.0',
#    'Income Tax Expense': '15685000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '45687000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '45687000000.0',
#    'EPS': '8.35',
#    'EPS Diluted': '8.31',
#    'Weighted Average Shs Out': '5470820000.0',
#    'Weighted Average Shs Out (Dil)': '5500281000.0',
#    'Dividend per Share': '2.18',
#    'Gross Margin': '0.3908',
#    'EBITDA Margin': '0.333',
#    'EBIT Margin': '0.2846',
#    'Profit Margin': '0.212',
#    'Free Cash Flow margin': '0.2481',
#    'EBITDA': '71877000000.0',
#    'EBIT': '61372000000.0',
#    'Consolidated Income': '45687000000.0',
#    'Earnings Before Tax Margin': '0.2846',
#    'Net Profit Margin': '0.2119'},
#   {'date': '2015-09-26',
#    'Revenue': '233715000000.0',
#    'Revenue Growth': '0.2786',
#    'Cost of Revenue': '140089000000.0',
#    'Gross Profit': '93626000000.0',
#    'R&D Expenses': '8067000000.0',
#    'SG&A Expense': '14329000000.0',
#    'Operating Expenses': '22396000000.0',
#    'Operating Income': '71230000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '72515000000.0',
#    'Income Tax Expense': '19121000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '53394000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '53394000000.0',
#    'EPS': '9.28',
#    'EPS Diluted': '9.22',
#    'Weighted Average Shs Out': '5753421000.0',
#    'Weighted Average Shs Out (Dil)': '5793069000.0',
#    'Dividend per Share': '1.98',
#    'Gross Margin': '0.4006',
#    'EBITDA Margin': '0.358',
#    'EBIT Margin': '0.3103',
#    'Profit Margin': '0.228',
#    'Free Cash Flow margin': '0.2986',
#    'EBITDA': '83772000000.0',
#    'EBIT': '72515000000.0',
#    'Consolidated Income': '53394000000.0',
#    'Earnings Before Tax Margin': '0.3103',
#    'Net Profit Margin': '0.2285'},
#   {'date': '2014-09-27',
#    'Revenue': '182795000000.0',
#    'Revenue Growth': '0.0695',
#    'Cost of Revenue': '112258000000.0',
#    'Gross Profit': '70537000000.0',
#    'R&D Expenses': '6041000000.0',
#    'SG&A Expense': '11993000000.0',
#    'Operating Expenses': '18034000000.0',
#    'Operating Income': '52503000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '53483000000.0',
#    'Income Tax Expense': '13973000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '39510000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '39510000000.0',
#    'EPS': '6.49',
#    'EPS Diluted': '6.45',
#    'Weighted Average Shs Out': '6085572000.0',
#    'Weighted Average Shs Out (Dil)': '6122663000.0',
#    'Dividend per Share': '1.811',
#    'Gross Margin': '0.3859',
#    'EBITDA Margin': '0.336',
#    'EBIT Margin': '0.2926',
#    'Profit Margin': '0.216',
#    'Free Cash Flow margin': '0.273',
#    'EBITDA': '61429000000.0',
#    'EBIT': '53483000000.0',
#    'Consolidated Income': '39510000000.0',
#    'Earnings Before Tax Margin': '0.2926',
#    'Net Profit Margin': '0.2161'},
#   {'date': '2013-09-28',
#    'Revenue': '170910000000.0',
#    'Revenue Growth': '0.092',
#    'Cost of Revenue': '106606000000.0',
#    'Gross Profit': '64304000000.0',
#    'R&D Expenses': '4475000000.0',
#    'SG&A Expense': '10830000000.0',
#    'Operating Expenses': '15305000000.0',
#    'Operating Income': '48999000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '50155000000.0',
#    'Income Tax Expense': '13118000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '37037000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '37037000000.0',
#    'EPS': '5.72',
#    'EPS Diluted': '5.68',
#    'Weighted Average Shs Out': '6477320000.0',
#    'Weighted Average Shs Out (Dil)': '6521634000.0',
#    'Dividend per Share': '1.629',
#    'Gross Margin': '0.3762',
#    'EBITDA Margin': '0.333',
#    'EBIT Margin': '0.2935',
#    'Profit Margin': '0.217',
#    'Free Cash Flow margin': '0.2609',
#    'EBITDA': '56912000000.0',
#    'EBIT': '50155000000.0',
#    'Consolidated Income': '37037000000.0',
#    'Earnings Before Tax Margin': '0.2935',
#    'Net Profit Margin': '0.2167'},
#   {'date': '2012-09-29',
#    'Revenue': '156508000000.0',
#    'Revenue Growth': '0.4458',
#    'Cost of Revenue': '87846000000.0',
#    'Gross Profit': '68662000000.0',
#    'R&D Expenses': '3381000000.0',
#    'SG&A Expense': '10040000000.0',
#    'Operating Expenses': '13421000000.0',
#    'Operating Income': '55241000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '55763000000.0',
#    'Income Tax Expense': '14030000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '41733000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '41733000000.0',
#    'EPS': '6.38',
#    'EPS Diluted': '6.31',
#    'Weighted Average Shs Out': '6543726000.0',
#    'Weighted Average Shs Out (Dil)': '6617483000.0',
#    'Dividend per Share': '0.379',
#    'Gross Margin': '0.4387',
#    'EBITDA Margin': '0.377',
#    'EBIT Margin': '0.3563',
#    'Profit Margin': '0.267',
#    'Free Cash Flow margin': '0.2649',
#    'EBITDA': '59040000000.0',
#    'EBIT': '55763000000.0',
#    'Consolidated Income': '41733000000.0',
#    'Earnings Before Tax Margin': '0.3563',
#    'Net Profit Margin': '0.2667'},
#   {'date': '2011-09-24',
#    'Revenue': '108249000000.0',
#    'Revenue Growth': '0.6596',
#    'Cost of Revenue': '64431000000.0',
#    'Gross Profit': '43818000000.0',
#    'R&D Expenses': '2429000000.0',
#    'SG&A Expense': '7599000000.0',
#    'Operating Expenses': '10028000000.0',
#    'Operating Income': '33790000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '34205000000.0',
#    'Income Tax Expense': '8283000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '25922000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '25922000000.0',
#    'EPS': '4.007',
#    'EPS Diluted': '3.954',
#    'Weighted Average Shs Out': '6469806000.0',
#    'Weighted Average Shs Out (Dil)': '6556515000.0',
#    'Dividend per Share': '0.0',
#    'Gross Margin': '0.4048',
#    'EBITDA Margin': '0.333',
#    'EBIT Margin': '0.316',
#    'Profit Margin': '0.239',
#    'Free Cash Flow margin': '0.2779',
#    'EBITDA': '36019000000.0',
#    'EBIT': '34205000000.0',
#    'Consolidated Income': '25922000000.0',
#    'Earnings Before Tax Margin': '0.316',
#    'Net Profit Margin': '0.2395'},
#   {'date': '2010-09-25',
#    'Revenue': '65225000000.0',
#    'Revenue Growth': '0.5202',
#    'Cost of Revenue': '39541000000.0',
#    'Gross Profit': '25684000000.0',
#    'R&D Expenses': '1782000000.0',
#    'SG&A Expense': '5517000000.0',
#    'Operating Expenses': '7299000000.0',
#    'Operating Income': '18385000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '18540000000.0',
#    'Income Tax Expense': '4527000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '14013000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '14013000000.0',
#    'EPS': '2.201',
#    'EPS Diluted': '2.164',
#    'Weighted Average Shs Out': '6366227000.0',
#    'Weighted Average Shs Out (Dil)': '6472984000.0',
#    'Dividend per Share': '0.0',
#    'Gross Margin': '0.3938',
#    'EBITDA Margin': '0.3',
#    'EBIT Margin': '0.2842',
#    'Profit Margin': '0.215',
#    'Free Cash Flow margin': '0.2526',
#    'EBITDA': '19567000000.0',
#    'EBIT': '18540000000.0',
#    'Consolidated Income': '14013000000.0',
#    'Earnings Before Tax Margin': '0.2842',
#    'Net Profit Margin': '0.2148'},
#   {'date': '2009-09-26',
#    'Revenue': '42905000000.0',
#    'Revenue Growth': '0.1444',
#    'Cost of Revenue': '25683000000.0',
#    'Gross Profit': '17222000000.0',
#    'R&D Expenses': '1333000000.0',
#    'SG&A Expense': '4149000000.0',
#    'Operating Expenses': '5482000000.0',
#    'Operating Income': '11740000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '12066000000.0',
#    'Income Tax Expense': '3831000000.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '8235000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '8235000000.0',
#    'EPS': '1.317',
#    'EPS Diluted': '1.297',
#    'Weighted Average Shs Out': '6251112000.0',
#    'Weighted Average Shs Out (Dil)': '6349035000.0',
#    'Dividend per Share': '0.0',
#    'Gross Margin': '0.4014',
#    'EBITDA Margin': '0.298',
#    'EBIT Margin': '0.2812',
#    'Profit Margin': '0.192',
#    'Free Cash Flow margin': '0.2085',
#    'EBITDA': '12800000000.0',
#    'EBIT': '12066000000.0',
#    'Consolidated Income': '8235000000.0',
#    'Earnings Before Tax Margin': '0.2812',
#    'Net Profit Margin': '0.1919'}]}

# %%
pd.DataFrame(Json['financials'])
# Out:
#   Consolidated Income Cost of Revenue Dividend per Share           EBIT  \
# 0       59531000000.0  163756000000.0               2.72  72903000000.0
# 1       48351000000.0  141048000000.0                2.4  64089000000.0
# 2       45687000000.0  131376000000.0               2.18  61372000000.0
# 3       53394000000.0  140089000000.0               1.98  72515000000.0
# 4       39510000000.0  112258000000.0              1.811  53483000000.0
# 5       37037000000.0  106606000000.0              1.629  50155000000.0
# 6       41733000000.0   87846000000.0              0.379  55763000000.0
# 7       25922000000.0   64431000000.0                0.0  34205000000.0
# 8       14013000000.0   39541000000.0                0.0  18540000000.0
# 9        8235000000.0   25683000000.0                0.0  12066000000.0
#
#   EBIT Margin         EBITDA EBITDA Margin    EPS EPS Diluted  \
# 0      0.2745  83806000000.0         0.316  12.01       11.91
# 1      0.2796  74246000000.0         0.324   9.27        9.21
# 2      0.2846  71877000000.0         0.333   8.35        8.31
# 3      0.3103  83772000000.0         0.358   9.28        9.22
# 4      0.2926  61429000000.0         0.336   6.49        6.45
# 5      0.2935  56912000000.0         0.333   5.72        5.68
# 6      0.3563  59040000000.0         0.377   6.38        6.31
# 7       0.316  36019000000.0         0.333  4.007       3.954
# 8      0.2842  19567000000.0           0.3  2.201       2.164
# 9      0.2812  12800000000.0         0.298  1.317       1.297
#
#   Earnings Before Tax Margin  ... Operating Income Preferred Dividends  \
# 0                     0.2745  ...    70898000000.0                 0.0
# 1                     0.2796  ...    61344000000.0                 0.0
# 2                     0.2846  ...    60024000000.0                 0.0
# 3                     0.3103  ...    71230000000.0                 0.0
# 4                     0.2926  ...    52503000000.0                 0.0
# 5                     0.2935  ...    48999000000.0                 0.0
# 6                     0.3563  ...    55241000000.0                 0.0
# 7                      0.316  ...    33790000000.0                 0.0
# 8                     0.2842  ...    18385000000.0                 0.0
# 9                     0.2812  ...    11740000000.0                 0.0
#
#   Profit Margin   R&D Expenses         Revenue Revenue Growth   SG&A Expense  \
# 0         0.224  14236000000.0  265595000000.0         0.1586  16705000000.0
# 1         0.211  11581000000.0  229234000000.0          0.063  15261000000.0
# 2         0.212  10045000000.0  215639000000.0        -0.0773  14194000000.0
# 3         0.228   8067000000.0  233715000000.0         0.2786  14329000000.0
# 4         0.216   6041000000.0  182795000000.0         0.0695  11993000000.0
# 5         0.217   4475000000.0  170910000000.0          0.092  10830000000.0
# 6         0.267   3381000000.0  156508000000.0         0.4458  10040000000.0
# 7         0.239   2429000000.0  108249000000.0         0.6596   7599000000.0
# 8         0.215   1782000000.0   65225000000.0         0.5202   5517000000.0
# 9         0.192   1333000000.0   42905000000.0         0.1444   4149000000.0
#
#   Weighted Average Shs Out Weighted Average Shs Out (Dil)        date
# 0             4955377000.0                   5000109000.0  2018-09-29
# 1             5217242000.0                   5251692000.0  2017-09-30
# 2             5470820000.0                   5500281000.0  2016-09-24
# 3             5753421000.0                   5793069000.0  2015-09-26
# 4             6085572000.0                   6122663000.0  2014-09-27
# 5             6477320000.0                   6521634000.0  2013-09-28
# 6             6543726000.0                   6617483000.0  2012-09-29
# 7             6469806000.0                   6556515000.0  2011-09-24
# 8             6366227000.0                   6472984000.0  2010-09-25
# 9             6251112000.0                   6349035000.0  2009-09-26
#
# [10 rows x 32 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
