# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-summary"

querystring = {"region":"US","lang":"en"}

headers = {
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com",
    'x-rapidapi-key': "6e1d2f09f2mshb480a02ffa9ae87p1dca27jsn5bc4d6b858ca"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"marketSummaryResponse":{"result":[{"fullExchangeName":"SNP","exchangeTimezoneName":"America/New_York","symbol":"^GSPC","regularMarketChange":{"raw":0.060058594,"fmt":"0.06"},"gmtOffSetMilliseconds":-14400000,"exchangeDataDelayedBy":0,"language":"en","regularMarketTime":{"raw":1568924401,"fmt":"4:20PM EDT"},"exchangeTimezoneShortName":"EDT","regularMarketChangePercent":{"raw":0.001997472,"fmt":"0.00%"},"quoteType":"INDEX","marketState":"POST","regularMarketPrice":{"raw":3006.79,"fmt":"3,006.79"},"market":"us_market","priceHint":2,"tradeable":false,"exchange":"SNP","sourceInterval":15,"shortName":"S&P 500","region":"US","regularMarketPreviousClose":{"raw":3006.73,"fmt":"3,006.73"},"triggerable":true},{"fullExchangeName":"DJI","exchangeTimezoneName":"America/New_York","symbol":"^DJI","regularMarketChange":{"raw":-52.291016,"fmt":"-52.29"},"gmtOffSetMilliseconds":-14400000,"exchangeDataDelayedBy":0,"language":"en","regularMarketTime":{"raw":1568924400,"fmt":"4:20PM EDT"},"exchangeTimezoneShortName":"EDT","regularMarketChangePercent":{"raw":-0.19262114,"fmt":"-0.19%"},"quoteType":"INDEX","marketState":"POST","regularMarketPrice":{"raw":27094.79,"fmt":"27,094.79"},"market":"us_market","priceHint":2,"tradeable":false,"exchange":"DJI","sourceInterval":120,"shortName":"Dow 30","region":"US","regularMarketPreviousClose":{"raw":27147.1,"fmt":"27,147.10"},"triggerable":true},{"fullExchangeName":"Nasdaq GIDS","exchangeTimezoneName":"America/New_York","symbol":"^IXIC","regularMarketChange":{"raw":5.487793,"fmt":"5.49"},"gmtOffSetMilliseconds":-14400000,"exchangeDataDelayedBy":0,"language":"en","regularMarketTime":{"raw":1568926046,"fmt":"4:47PM EDT"},"exchangeTimezoneShortName":"EDT","regularMarketChangePercent":{"raw":0.06710933,"fmt":"0.07%"},"quoteType":"INDEX","marketState":"POST","regularMarketPrice":{"raw":8182.8794,"fmt":"8,182.88"},"market":"us_market","priceHint":2,"tradeable":false,"exchange":"NIM","sourceInterval":15,"shortName":"Nasdaq","region":"US","regularMarketPreviousClose":{"raw":8177.3916,"fmt":"8,177.39"},"triggerable":false},{"fullExchangeName":"Chicago Options","exchangeTimezoneName":"America/New_York","symbol":"^RUT","regularMarketChange":{"raw":-6.869751,"fmt":"-6.87"},"gmtOffSetMilliseconds":-14400000,"exchangeDataDelayedBy":20,"language":"en","regularMarketTime":{"raw":1568925005,"fmt":"4:30PM EDT"},"exchangeTimezoneShortName":"EDT","regularMarketChangePercent":{"raw":-0.43802574,"fmt":"-0.44%"},"quoteType":"INDEX","marketState":"POST","regularMarketPrice":{"raw":1561.4744,"fmt":"1,561.47"},"market":"us_market","priceHint":2,"tradeable":false,"exchange":"WCB","sourceInterval":15,"shortName":"Russell 2000","region":"US","regularMarketPreviousClose":{"raw":1568.3441,"fmt":"1,568.34"},"triggerable":false},{"fullExchangeName":"NY Mercantile","exchangeTimezoneName":"America/New_York","symbol":"CL=F","regularMarketChange":{"raw":0.5099983,"fmt":"0.51"},"headSymbolAsString":"CL=F","gmtOffSetMilliseconds":-14400000,"exchangeDataDelayedBy":30,"language":"en","regularMarketTime":{"raw":1568925389,"fmt":"4:36PM EDT"},"exchangeTimezoneShortName":"EDT","regularMarketChangePercent":{"raw":0.8776429,"fmt":"0.88%"},"quoteType":"FUTURE","marketState":"REGULAR","regularMarketPrice":{"raw":58.62,"fmt":"58.62"},"market":"us24_market","tradeable":false,"exchange":"NYM","sourceInterval":30,"shortName":"Crude Oil","region":"US","regularMarketPreviousClose":{"raw":58.11,"fmt":"58.11"},"triggerable":false},{"fullExchangeName":"COMEX","exchangeTimezoneName":"America/New_York","symbol":"GC=F","regularMarketChange":{"raw":-9.700073,"fmt":"-9.70"},"headSymbolAsString":"GC=F","gmtOffSetMilliseconds":-14400000,"exchangeDataDelayedBy":30,"language":"en","regularMarketTime":{"raw":1568925443,"fmt":"4:37PM EDT"},"exchangeTimezoneShortName":"EDT","regularMarketChangePercent":{"raw":-0.6399309,"fmt":"-0.64%"},"quoteType":"FUTURE","marketState":"REGULAR","regularMarketPrice":{"raw":1506.1,"fmt":"1,506.10"},"market":"us24_market","tradeable":false,"e ...
