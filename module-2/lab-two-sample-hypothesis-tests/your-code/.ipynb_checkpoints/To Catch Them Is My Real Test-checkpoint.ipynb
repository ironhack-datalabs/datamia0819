# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind
from scipy.stats import ttest_1samp
from scipy.stats import chi2_contingency

# %% [markdown]
# # Challenge 1 - Independent Sample T-tests
#
# In this challenge, we will be using the Pokemon dataset. Before applying statistical methods to this data, let's first examine the data.
#
# To load the data, run the code below.

# %%
# Run this code:

pokemon = pd.read_csv(r'C:\Users\Repairmanmanmanman\test\datamia0819\module-2\lab-df-calculation-and-transformation\your-code\Pokemon.csv')

# %% [markdown]
# Let's start off by looking at the `head` function in the cell below.

# %%
# Your code here:
pokemon.head(300)
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison    318  45      49       49
# 1      2                Ivysaur   Grass  Poison    405  60      62       63
# 2      3               Venusaur   Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4      4             Charmander    Fire     NaN    309  39      52       43
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 295  272               Ludicolo   Water   Grass    480  80      70       70
# 296  273                 Seedot   Grass     NaN    220  40      40       50
# 297  274                Nuzleaf   Grass    Dark    340  70      70       40
# 298  275                Shiftry   Grass    Dark    480  90     100       60
# 299  276                Taillow  Normal  Flying    270  40      55       30
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# The first thing we would like to do is compare the legendary Pokemon to the regular Pokemon. To do this, we should examine the data further. What is the count of legendary vs. non legendary Pokemons?

# %%
# Your code here:
pokemon[pokemon['Legendary']== True]
Legendary = pd.DataFrame(pokemon[pokemon['Legendary']== True])
pokemon[pokemon['Legendary']== False]
Regular = pd.DataFrame(pokemon[pokemon['Legendary']== False])
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count   65.000000   65.000000   65.000000   65.000000   65.000000   65.000000
# mean   470.215385  637.384615   92.738462  116.676923   99.661538  122.184615
# std    173.651095   60.937389   21.722164   30.348037   28.255131   31.104608
# min    144.000000  580.000000   50.000000   50.000000   20.000000   50.000000
# 25%    381.000000  580.000000   80.000000  100.000000   90.000000  100.000000
# 50%    483.000000  600.000000   91.000000  110.000000  100.000000  120.000000
# 75%    642.000000  680.000000  105.000000  131.000000  115.000000  150.000000
# max    721.000000  780.000000  150.000000  190.000000  200.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count   65.000000   65.000000   65.000000
# mean   105.938462  100.184615    3.769231
# std     28.827004   22.952323    1.455262
# min     20.000000   50.000000    1.000000
# 25%     90.000000   90.000000    3.000000
# ...

# %% [markdown]
# Compute the mean and standard deviation of the total points for both legendary and non-legendary Pokemon.

# %%
# Your code here:
Legendary.describe()
#Total Mean = ~637.38
#Total STD = ~60.94
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count   65.000000   65.000000   65.000000   65.000000   65.000000   65.000000
# mean   470.215385  637.384615   92.738462  116.676923   99.661538  122.184615
# std    173.651095   60.937389   21.722164   30.348037   28.255131   31.104608
# min    144.000000  580.000000   50.000000   50.000000   20.000000   50.000000
# 25%    381.000000  580.000000   80.000000  100.000000   90.000000  100.000000
# 50%    483.000000  600.000000   91.000000  110.000000  100.000000  120.000000
# 75%    642.000000  680.000000  105.000000  131.000000  115.000000  150.000000
# max    721.000000  780.000000  150.000000  190.000000  200.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count   65.000000   65.000000   65.000000
# mean   105.938462  100.184615    3.769231
# std     28.827004   22.952323    1.455262
# min     20.000000   50.000000    1.000000
# 25%     90.000000   90.000000    3.000000
# ...

# %%
Regular.describe()
#Total Mean = 417.21
#Total STD = 106.76
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean   353.315646  417.213605   67.182313   75.669388   71.559184   68.454422
# std    208.590419  106.760417   24.808849   30.490153   30.408194   29.091705
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    175.500000  324.000000   50.000000   54.500000   50.000000   45.000000
# 50%    346.000000  425.000000   65.000000   72.000000   66.000000   65.000000
# 75%    533.500000  498.000000   79.500000   95.000000   85.000000   85.000000
# max    715.000000  700.000000  255.000000  185.000000  230.000000  175.000000
#
#           Sp. Def       Speed  Generation
# count  735.000000  735.000000  735.000000
# mean    68.892517   65.455782    3.284354
# std     25.669310   27.843038    1.673471
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %% [markdown]
# The computation of the mean might give us a clue regarding how the statistical test may turn out; However, it certainly does not prove whether there is a significant difference between the two groups.
#
# In the cell below, use the `ttest_ind` function in `scipy.stats` to compare the the total points for legendary and non-legendary Pokemon. Since we do not have any information about the population, assume the variances are not equal.

# %%
# Your code here:

ttest_ind(Legendary['Total'], Regular['Total'], equal_var=False)
# Out:
# Ttest_indResult(statistic=25.8335743895517, pvalue=9.357954335957446e-47)

# %% [markdown]
# What do you conclude from this test? Write your conclusions below.

# %%
# Your conclusions here:
#Based on my solution, the pvalue indicates a HUGE difference between the
#sample means. This is true since Legendaries have much better stats than
#regular Pokemon, hence the name.

# %% [markdown]
# How about we try to compare the different types of pokemon? In the cell below, list the types of Pokemon from column `Type 1` and the count of each type.

# %%
# Your code here:
pokemon.groupby(['Type 1']).size().reset_index(name='counts')
# Out:
#       Type 1  counts
# 0        Bug      69
# 1       Dark      31
# 2     Dragon      32
# 3   Electric      44
# 4      Fairy      17
# 5   Fighting      27
# 6       Fire      52
# 7     Flying       4
# 8      Ghost      32
# 9      Grass      70
# 10    Ground      32
# 11       Ice      24
# 12    Normal      98
# 13    Poison      28
# 14   Psychic      57
# 15      Rock      44
# 16     Steel      27
# 17     Water     112

# %% [markdown]
# Since water is the largest group of Pokemon, compare the mean and standard deviation of water Pokemon to all other Pokemon.

# %%
# Your code here:
Water = pd.DataFrame(pokemon[pokemon['Type 1']== 'Water'])
Water.describe()
#Water Total Mean = 430.46
#Water Total STD = 113.19
#Total Water Types = 112
Non_Water = pd.DataFrame(pokemon[pokemon['Type 1']!= 'Water'])
Non_Water.describe()
#Non Water Total Mean = 435.86
#Non Water Total STD = 121.09
#Total Non Water Types = 688
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  688.000000  688.000000  688.000000  688.000000  688.000000  688.000000
# mean   372.536337  435.859012   68.802326   79.790698   73.988372   72.495640
# std    209.928799  121.091682   25.194299   33.025152   31.719933   33.292537
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    197.750000  330.000000   50.000000   55.000000   50.000000   45.000000
# 50%    380.000000  450.000000   65.000000   76.000000   70.000000   65.000000
# 75%    553.250000  515.000000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  688.000000  688.000000  688.000000
# mean    72.127907   68.654070    3.399709
# std     27.739292   29.925907    1.666119
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %% [markdown]
# Perform a hypothesis test comparing the mean of total points for water Pokemon to all non-water Pokemon. Assume the variances are equal.

# %%
# Your code here:
ttest_ind(Water['Total'], Non_Water['Total'], equal_var=True)
# Out:
# Ttest_indResult(statistic=-0.4418547448849676, pvalue=0.6587140317488793)

# %% [markdown]
# Write your conclusion below.

# %%
# Your conclusions here:
#Based on the pvalue being greater than .05 it means that the means are
#not statiscially different. That means that even though Water types are
#the most numerous it does not mean they are better or worse than any other.

# %% [markdown]
# # Challenge 2 - Matched Pairs Test
#
# In this challenge we will compare dependent samples of data describing our Pokemon. Our goal is to see whether there is a significant difference between each Pokemon's defense and attack scores. Our hypothesis is that the defense and attack scores are equal. In the cell below, import the `ttest_rel` function from `scipy.stats` and compare the two columns to see if there is a statistically significant difference between them.

# %%
# Your code here:
from scipy.stats import ttest_rel
ttest_rel(pokemon['Attack'], pokemon['Defense'])
# Out:
# Ttest_relResult(statistic=4.325566393330478, pvalue=1.7140303479358558e-05)

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:
#Based on my results, these values are statistically different because the
#p value is much smaller than .025 so this must be rejected.
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# We are also curious about whether therer is a significant difference between the mean of special defense and the mean of special attack. Perform the hypothesis test in the cell below.

# %%
# Your code here:
ttest_rel(pokemon['Sp. Atk'], pokemon['Sp. Def'])
# Out:
# Ttest_relResult(statistic=0.853986188453353, pvalue=0.3933685997548122)

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:
#It appears that there is not much difference between Sp. Atk and Sp. Def
#due to the pvalue being greater than .025.

# %% [markdown]
# As you may recall, a two sample matched pairs test can also be expressed as a one sample test of the difference between the two dependent columns.
#
# Import the `ttest_1samp` function and perform a one sample t-test of the difference between defense and attack. Test the hypothesis that the difference between the means is zero. Confirm that the results of the test are the same.

# %%
# Your code here:
ttest_1samp(pokemon['Defense']-pokemon['Attack'], 0)
#These values are abolutely not the same as 0. Reject the null.
# Out:
# Ttest_1sampResult(statistic=-4.325566393330478, pvalue=1.7140303479358558e-05)

# %% [markdown]
# # Bonus Challenge - The Chi-Square Test
#
# The Chi-Square test is used to determine whether there is a statistically significant difference in frequencies. In other words, we are testing whether there is a relationship between categorical variables or rather when the variables are independent. This test is an alternative to Fisher's exact test and is used in scenarios where sample sizes are larger. However, with a large enough sample size, both tests produce similar results. Read more about the Chi Squared test [here](https://en.wikipedia.org/wiki/Chi-squared_test).
#
# In the cell below, create a contingency table using `pd.crosstab` comparing whether a Pokemon is legenadary or not and whether the Type 1 of a Pokemon is water or not.

# %%
# Your code here:
Compare = pd.crosstab(pokemon['Type 1']=='Water',pokemon['Legendary'])

# %% [markdown]
# Perform a chi-squared test using the `chi2_contingency` function in `scipy.stats`. You can read the documentation of the function [here](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.chi2_contingency.html).

# %%
# Your code here:
chi2_contingency(Compare)
# Out:
# (2.9429200762850503, 0.08625467249550949, 1, array([[632.1,  55.9],
#         [102.9,   9.1]]))

# %% [markdown]
# Based on a 95% confidence, should we reject the null hypothesis?

# %%
# Your answer here:
#Yes because the p of the chi2 test is greater than 0.05, so that means
#the variables testes are independent. Meaning just because there are
#more waters does not mean there are more Water Legendaries.
