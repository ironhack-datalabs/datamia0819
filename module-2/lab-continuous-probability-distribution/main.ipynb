# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform

x = uniform.rvs(size = 10)
a = 1
b = 5
randoms = a + (b - a) * x
randoms
# Out:
# array([4.19484016, 2.209903  , 2.91523645, 4.55609636, 4.35746867,
#        4.62720977, 1.87271449, 1.44269724, 1.34259911, 4.16654672])

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

lowers = [10, 10]
uppers = [15, 60]
sizes = [100, 1000]
bins = 10

fig, ax = plt.subplots(1, 2, figsize = (8, 5))
fig.subplots_adjust(hspace = 0, wspace = .3)

for i in range(len(counts)):
    x = uniform.rvs(size = counts[i])
    a = lowers[i]
    b = uppers[i]
    randoms = a + (b - a) * x
    sns.distplot(randoms, kde = False, bins = bins, fit = uniform, ax = ax[i], hist_kws = {'edgecolor': 'w'})
    ax[i].set_title('Uniform ' + str(i))
    ax[i].set_xlabel('x')
    if i == 0:
        ax[i].set_ylabel('P(x)')

# %% [markdown]
# How are the two distributions different?

# %%
# Uniform 0 seems to vary more from the ideal uniform distribution than Uniform 1, which is likely due to the sample size 
# difference. in addition, the domains vary and are shown in the different x-axes of the histograms.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

mus = [10, 10]
sigmas = [1, 50]
sizes = [1000, 1000]

fig, ax = plt.subplots(1, 2, figsize = (8, 5))
fig.subplots_adjust(hspace = 0, wspace = .3)

for i in range(len(count)):
    x = norm.rvs(size = sizes[i])
    randoms = x * sigmas[i] + mus[i]
    sns.distplot(randoms, kde = False, fit = norm, ax = ax[i], hist_kws = {'edgecolor': 'w'})
    ax[i].set_title('Normal ' + str(i))
    ax[i].set_xlabel('x')
    if i == 0:
        ax[i].set_ylabel('P(x)')

# %% [markdown]
# How are the two distributions different?

# %%
# Normal 0 and Normal 1 are centered around about the same value (supposed to be 10). However, the difference in the 
# standard deviations results in very different domains in the histograms. Normal 0 varies within 6 and 14, while Normal 1 
# varies within -120 and 120. Both look relatively normal, which is likely due to the large sample sizes in both sets.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd

vehicles = pd.read_csv('vehicles.csv')
columns = ['Fuel Barrels/Year', 'CO2 Emission Grams/Mile', 'Combined MPG']

palette = 'tab20'

fig, ax = plt.subplots(1, 3, figsize = (15, 5))
fig.subplots_adjust(hspace = 0, wspace = .3)

for i in range(len(columns)):
    sns.distplot(vehicles[columns[i]], kde = False, color = sns.color_palette(palette)[i], fit = norm, ax = ax[i], hist_kws = {'edgecolor': 'w'})
    ax[i].set_xlabel(columns[i])
    if i == 0:
        ax[i].set_ylabel('P(x)')

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %% [markdown]
# 3. Combined MPG

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# If I had to pick one, it would definitely be Combined MPG because the bars hug the normal curve way more than the other 
# two. However, Generally, I would say that they could all be described as approximately normal, although the relative 
# frequencies on the higher end of Fuel Barrels/Year and CO2 Emission Grams/Mile are a bit more volatile.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
from scipy.stats import expon
import math

lam = .1
sizes = [10, 10000]
bins = 100

fig, ax = plt.subplots(1, 2, figsize = (15, 5))
fig.subplots_adjust(hspace = 0, wspace = .2)

for i in range(len(sizes)):
    x = expon.rvs(size = sizes[i])
    randoms = x / lam
    sns.distplot(randoms, kde = False, fit = expon, bins = bins, ax = ax[i], hist_kws = {'edgecolor': 'w'})
    ax[i].set_title('Exponential ' + str(i))
    ax[i].set_xlabel('x')
    ax[i].set_xlim(0, None)
    if i == 0:
        ax[i].set_ylabel('P(x)')

# %% [markdown]
# How are the two distributions different?

# %%
# Exponential 0 hardly looks like an exponential distribution at all, which is likely due to the small sample size. 
# Exponential 1 hugs the exponential fit line well, meaning it is approximately exponential. In addition, the probability 
# values for Exponential 0 are much larger than those of Exponential 1.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
def exponential_pdf(x, lam):
    return lam * math.exp(-lam * x)

def exponential_cdf(x, lam):
    prob = 0
    for i in range(x + 1):
        prob = prob + exponential_pdf(i, lam)
    return prob

x = 14
lam = .1

exponential_cdf(x, lam)
# Out:
# 0.8163606155044532

# %%
distribution_data = {'x': [], 'P(X <= x)': []}

lam = .1

for i in range(30):
    distribution_data['x'].append(i)
    distribution_data['P(X <= x)'].append(exponential_pdf(i, lam))

distribution_data
distribution = pd.DataFrame(distribution_data)

sns.set_style('ticks')
sns.barplot(x = 'x', y = 'P(X <= x)', color = sns.color_palette('tab20')[1], data = distribution, alpha = .8)
plt.title('Exponential CMF')
# Out:
# Text(0.5, 1.0, 'Exponential CMF')

# %%
distribution_data = {'x': [], 'P(X <= x)': []}

lam = .1

for i in range(30):
    distribution_data['x'].append(i)
    distribution_data['P(X <= x)'].append(exponential_cdf(i, lam))

distribution_data
distribution = pd.DataFrame(distribution_data)

sns.set_style('ticks')
sns.barplot(x = 'x', y = 'P(X <= x)', color = sns.color_palette('tab20')[0], data = distribution, alpha = .8)
plt.title('Exponential CMF')
# Out:
# Text(0.5, 1.0, 'Exponential CMF')

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
x = 15
lam = .1

1 - exponential_cdf(x, lam)
# Out:
# 0.1613263684807038
